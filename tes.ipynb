# %%
import pandas as pd
from pycaret.classification import *

data = pd.read_csv('dataset_final.csv')

x = setup(data, target='risiko_gerd', session_id=123)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 6
#       2 from pycaret.classification import *
#       4 data = pd.read_csv('dataset_final.csv')
# ----> 6 x = setup(data, target='risiko_gerd', session_id=123)
#
# ...
